# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt



team_f1 = ["Red Bull", "Mercedes", "McLaren", "Ferrari"]
drivers_f1 = ["Max Verstappen", "Lewis Hamilton", "Lando Norris", "Charles Leclerc"]
ranking_teams = [1, 2, 3, 4]
points = [30, 28, 26, 22]


print(team_f1)
print(drivers_f1)
print(ranking_teams)
print(points)


plt.plot(ranking_teams, points)
plt.show()
plt.pie(points, labels=team_f1, autopct="%1.1f%%")
plt.show()
plt.bar(team_f1, drivers_f1)
plt.show()
# Out:
# ['Red Bull', 'Mercedes', 'McLaren', 'Ferrari']
# ['Max Verstappen', 'Lewis Hamilton', 'Lando Norris', 'Charles Leclerc']
# [1, 2, 3, 4]
# [30, 28, 26, 22]
